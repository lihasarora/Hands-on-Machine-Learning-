# %%
## Importing liabraries
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from scipy import stats
from statistics import mean, median, stdev

## Display all outputs in the output
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import random as rd
import warnings

# %%
## Creating  sample population

rd.seed(10000)
## Update the distribution of the population 
mean,sd =0,15
array_random = np.random.lognormal(0,0.5 , size=10000)
sn.distplot(array_random,color="blue")

# %%
## Enter the sample size and sample counts below
size = 10
sample_count = 1000
df=pd.DataFrame([])
for k in range(0,sample_count):
    df[("x_"+str(k))] = array_random[[rd.randrange(start=0,stop=10000,step=1) for i in range(0,size)]]
    i=0

test = df.apply(lambda x: x.mean(), axis=0).reset_index()
test.columns = ["sample_number","sample_mean"]
sn.distplot(test.sample_mean,color="maroon",label="20")
